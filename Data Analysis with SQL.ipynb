# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/mohittomar2008/Customer-Churn-Analysis/main/Telecom_customer_churn.csv')

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
from pandasql import sqldf

pysqldf= lambda q:sqldf(q,globals())

# %%
q='select * from df'
pysqldf(q)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
q='select gender,Partner,tenure from df'
pysqldf(q)
# Out:
#       gender Partner  tenure
# 0     Female     Yes       1
# 1       Male      No      34
# 2       Male      No       2
# 3       Male      No      45
# 4     Female      No       2
# ...      ...     ...     ...
# 7038    Male     Yes      24
# 7039  Female     Yes      72
# 7040  Female     Yes      11
# 7041    Male     Yes       4
# 7042    Male      No      66
#
# [7043 rows x 3 columns]

# %%
q='select distinct gender,churn from df'
pysqldf(q)
# Out:
#    gender Churn
# 0  Female    No
# 1    Male    No
# 2    Male   Yes
# 3  Female   Yes

# %%
q='select distinct contract from df'
pysqldf(q)
# Out:
#          Contract
# 0  Month-to-month
# 1        One year
# 2        Two year

# %%
q='select count(distinct contract) from df'
pysqldf(q)
# Out:
#    count(distinct contract)
# 0                         3

# %%
q='select count(distinct gender) from df'
pysqldf(q)
# Out:
#    count(distinct gender)
# 0                       2

# %% [raw]
#  SQL where to filter records:
#
# select column1, column2
# from table_name
# where condition;

# %%
q='select * from df where gender="Female" and Partner="No" limit 5'
pysqldf(q)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9237-HQITU  Female              0      No         No       2          Yes
# 1  9305-CDSKC  Female              0      No         No       8          Yes
# 2  6713-OKOMC  Female              0      No         No      10           No
# 3  8191-XWSZG  Female              0      No         No      52          Yes
# 4  4183-MYFRB  Female              0      No         No      21          Yes
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0                No     Fiber optic                   No  ...
# 1               Yes     Fiber optic                   No  ...
# 2  No phone service             DSL                  Yes  ...
# 3                No              No  No internet service  ...
# 4                No     Fiber optic                   No  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
q='select * from df where gender="Female" and TotalCharges>820'
pysqldf(q)
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9305-CDSKC  Female              0      No         No       8
# 1    4080-IIARD  Female              0     Yes         No      13
# 2    3957-SQXML  Female              0     Yes        Yes      34
# 3    0557-ASKVU  Female              0     Yes        Yes      18
# 4    5698-BQJOH  Female              0      No         No       9
# ..          ...     ...            ...     ...        ...     ...
# 224  9940-HPQPG  Female              0     Yes         No       9
# 225  2511-ALLCS  Female              0     Yes        Yes      35
# 226  7746-AWNQW  Female              0      No         No      28
# 227  0804-YGEQV  Female              0     Yes        Yes      43
# 228  9710-NJERN  Female              0      No         No      39
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0            Yes               Yes     Fiber optic                   No  ...
# ...

# %%
q='select * from df where gender="Female" and InternetService in ("Fiber optic","DSL") limit 5'
pysqldf(q)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  9237-HQITU  Female              0      No         No       2          Yes
# 2  9305-CDSKC  Female              0      No         No       8          Yes
# 3  6713-OKOMC  Female              0      No         No      10           No
# 4  7892-POOKP  Female              0     Yes         No      28          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No     Fiber optic             No  ...               No
# 2               Yes     Fiber optic             No  ...              Yes
# 3  No phone service             DSL            Yes  ...               No
# 4               Yes     Fiber optic             No  ...              Yes
#
# ...

# %%
q='select * from df where gender="Male" and MultipleLines like "N%" limit 5'
pysqldf(q)
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  5575-GNVDE   Male              0      No         No      34          Yes
# 1  3668-QPYBK   Male              0      No         No       2          Yes
# 2  7795-CFOCW   Male              0      No         No      45           No
# 3  6388-TABGU   Male              0      No        Yes      62          Yes
# 4  9763-GRSKD   Male              0     Yes        Yes      13          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0                No             DSL            Yes  ...              Yes
# 1                No             DSL            Yes  ...               No
# 2  No phone service             DSL            Yes  ...              Yes
# 3                No             DSL            Yes  ...               No
# 4                No             DSL            Yes  ...               No
#
# ...

# %%
q='select * from df where not gender="Male" limit 3'
pysqldf(q)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  9237-HQITU  Female              0      No         No       2          Yes
# 2  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No     Fiber optic             No  ...               No
# 2               Yes     Fiber optic             No  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No  Month-to-month              Yes
# 2          No         Yes             Yes  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %% [markdown]
# ## Orderby

# %%
q='select * from df order by TotalCharges desc'
pysqldf(q)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     9093-FPDLG  Female              0      No         No      11
# 1     4536-PLEQY    Male              0     Yes         No      12
# 2     5899-MQZZL  Female              0      No         No      13
# 3     6051-PTVNS  Female              0     Yes        Yes      55
# 4     8249-THVEC    Male              0     Yes        Yes      51
# ...          ...     ...            ...     ...        ...     ...
# 7038  3213-VVOLG    Male              0     Yes        Yes       0
# 7039  2520-SGTTA  Female              0     Yes        Yes       0
# 7040  2923-ARZLG    Male              0     Yes        Yes       0
# 7041  4075-WKNIU  Female              0     Yes        Yes       0
# 7042  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes            No     Fiber optic                   No  ...
# ...

# %%
q='select MonthlyCharges,TotalCharges from df order by TotalCharges,MonthlyCharges desc'
pysqldf(q)
# Out:
#       MonthlyCharges TotalCharges
# 0              80.85
# 1              73.35
# 2              61.90
# 3              56.05
# 4              52.55
# ...              ...          ...
# 7038           19.40       997.75
# 7039           19.15        998.1
# 7040           75.00       999.45
# 7041           85.05        999.8
# 7042           94.20        999.9
#
# [7043 rows x 2 columns]

# %%
q='select PaymentMethod,TotalCharges from df order by TotalCharges,PaymentMethod desc'
pysqldf(q)
# Out:
#                 PaymentMethod TotalCharges
# 0                Mailed check
# 1                Mailed check
# 2                Mailed check
# 3                Mailed check
# 4                Mailed check
# ...                       ...          ...
# 7038             Mailed check       997.75
# 7039  Credit card (automatic)        998.1
# 7040             Mailed check       999.45
# 7041  Credit card (automatic)        999.8
# 7042         Electronic check        999.9
#
# [7043 rows x 2 columns]

# %%
q='select PaymentMethod,TotalCharges from df order by PaymentMethod,TotalCharges desc'
pysqldf(q)
# Out:
#                   PaymentMethod TotalCharges
# 0     Bank transfer (automatic)       997.65
# 1     Bank transfer (automatic)       996.95
# 2     Bank transfer (automatic)       996.45
# 3     Bank transfer (automatic)        994.8
# 4     Bank transfer (automatic)       994.55
# ...                         ...          ...
# 7038               Mailed check
# 7039               Mailed check
# 7040               Mailed check
# 7041               Mailed check
# 7042               Mailed check
#
# [7043 rows x 2 columns]

# %%
q='select * from df where TotalCharges is not null limit 2'
pysqldf(q)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
q='select * from df where TotalCharges is not null limit 2'
pysqldf(q)

# %% [markdown]
# ## Update

# %% [markdown]
# Used to modify existing records

# %% [raw]
# update table_name
# set column1=value1,column2=value2
# where condition

# %% [markdown]
# # Delete

# %% [raw]
# q='delete from df where SeniorCitizen=0 '
# pysqldf(q)

# %%
q='select count(*) from df'
pysqldf(q)
# Out:
#    count(*)
# 0      7043
